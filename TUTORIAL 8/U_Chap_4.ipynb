#  5 5 7 2 6 2 8 3 5 9 3 1 9 7 2 1 6 6 1 2 5 2 9 3 5 9 1 5 3 5 5 6 8 6 5 5 4
#  9 7 6 4 1 2 3 9 1 6 5 8 1 1 1 2 9 5 3 8 5 5 3 3 7 1 2 1 8 3 2 4 3 8 9 2 9
#  2 8 6 4 9 1 1 1 9 9 4 7 1 7 3 6 4 7 9 5 1 6 5 8 3 3 5 7 7 7 9 6 9 5 4 9 2
#  1 2 8 4 9 8 4 8 1 4 3 7 3 3 3 4 6 1 2 4 7 5 1 5 5 3 4 5 7 3 3 8 6 1 4 6 2
#  3 8 5 9 1 7 9 5 8 9 5 8 6 7 5 5 9 7 9 9 3 2 6 1 8 3 1 1 1 8 9 4 7 6 9 7 2
#  7 5 2 5 4 7 9 4 7 4 8 8 4 7 8 4 1 6 1 6 3 3 7 3 4 2 7 6 9 3 1 9 9 3 1 4 9
#  1 1 6 7 5 3 4 8 9 9 9 8 9 5 3 7 9 8 7 9 4 5 2 7 6 5 5 4 3 4 2 2 7 9 4 5 9
#  8]

# %%
plt.plot(data, marker='o',
linestyle='-', color='b')
plt.title("Line Plot Example")
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y, color='red',
marker='x')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatter Plot Example")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(x, y, marker='o',
linestyle='-', color='b')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Line Plot Example")
plt.show()

# %%
x = np.arange(1, 13)  # Months
y = np.array([45, 47, 52, 55, 61, 66,
              72, 68, 65, 60, 55, 50])  # Sales


plt.figure(figsize=(6, 3))
plt.plot(x, y, "C1--o", label="Monthly Sales")
plt.title("2023 Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales (K$)")
plt.legend()
plt.grid(alpha=1)
plt.tight_layout()
# plt.show()
plt.savefig(
    "Basic Styling.png",
    dpi=300,
    bbox_inches="tight",
    transparent=True,
)

# %%
x1 = np.linspace(0, 10, 100)
y1 = np.sin(x1)
hist_data = np.random.randn(1000)

fig, ax = plt.subplots(2, 1, figsize=(5, 5))
ax[0].plot(x1, y1, "tab:green")
ax[0].set_title("Trend")
ax[1].hist(data, bins=15, color="orange")
ax[1].set_title("Distribution")
fig.tight_layout()
plt.savefig("Subplot.png", dpi=300, bbox_inches="tight",  transparent=True,)

# %%
data = np.concatenate([
    np.random.normal(100, 10, 200),
    np.random.normal(80, 15, 100)
])
plt.figure(figsize=(6, 2))

plt.boxplot(
    data,
    vert=False,
    widths=0.6,
    patch_artist=True,
    boxprops={"facecolor": "lightblue", "alpha": 0.7},
    whiskerprops={"linewidth": 1.5},
    medianprops={"color": "red", "linewidth": 2},
)

plt.yticks([1], ["Dataset"])  # Single category label
plt.xlabel("Measurement Values")
plt.title("Distribution Analysis", pad=15)
plt.tight_layout()  # Prevent label cutoff
plt.savefig(
    "Boxplot.png",
    dpi=300,
    bbox_inches="tight",
    transparent=True,
)

# %%
np.random.seed(42)
df = pd.DataFrame(
    {
        "Category": np.random.choice(["A", "B", "C"], size=100),
        "Value1": np.random.normal(loc=50, scale=15, size=100),
        "Value2": np.random.normal(loc=30, scale=10, size=100),
        "Value3": np.random.normal(loc=70, scale=20, size=100),
    }
)

plt.figure(figsize=(6, 4))
sns.boxplot(x="Category", y="Value1", data=df)
plt.title("Box Plot")
plt.savefig(
    "sea_Boxplot.png",
    dpi=300,
    bbox_inches="tight",
    transparent=True,
)

# %%
plt.figure(figsize=(6, 4))

sns.violinplot(x="Category", y="Value1", data=df)
plt.title("Violin Plot")
plt.savefig(
    "sea_violin.png",
    dpi=300,
    bbox_inches="tight",
    transparent=True,
)

# %%
plt.figure(figsize=(6, 4))

pairplot = sns.pairplot(df, hue="Category")
plt.savefig(
    "sea_pair.png",
    dpi=300,
    bbox_inches="tight",
    transparent=True,
)

# %%
plt.subplot(2, 2, 3)
numeric_df = df.select_dtypes(include=["float64", "int64"])
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f", center=0)
plt.title("Correlation Heatmap (Numeric Columns)")
plt.savefig(
    "sea_corr.png",
    dpi=300,
    bbox_inches="tight",
    transparent=True,
)
